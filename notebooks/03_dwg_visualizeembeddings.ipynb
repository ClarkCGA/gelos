# %%
import geopandas as gpd
import os
import random
import pandas as pd
from pathlib import Path
import pyarrow as pa
from matplotlib.patches import Patch
import pyarrow.dataset as ds
import numpy as np
import yaml
from gelos import config
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from gelos.config import PROJ_ROOT, PROCESSED_DATA_DIR, DATA_VERSION, RAW_DATA_DIR
# Out:
# 2025-11-27 23:52:39.878 | INFO     | gelos.config:<module>:11 - PROJ_ROOT path is: /app

# %%
def sample_files(directory: str | Path, sample_size: int, *, seed: int | None = None) -> list[Path]:
    rng = random.Random(seed)
    directory = Path(directory)

    files = [Path(entry.path) for entry in os.scandir(directory) if entry.is_file()]
    if sample_size >= len(files):
        return files

    return rng.sample(files, sample_size)

# %%
yaml_config_directory = config.PROJ_ROOT / 'gelos' / 'configs'
yaml_name = 'terramind_embedding_generation.yaml'
# yaml_name = 'prithvi_eo_300m_embedding_generation.yaml'
with open(yaml_config_directory / yaml_name, "r") as f:
    yaml_config = yaml.safe_load(f)
print(yaml.dump(yaml_config))
# Out:
# data:
#   class_path: gelos.gelosdatamodule.GELOSDataModule
#   init_args:
#     bands:
#       DEM:
#       - DEM
#       S1RTC:
#       - VV
#       - VH
#       S2L2A:
#       - COASTAL_AEROSOL
#       - BLUE
#       - GREEN
#       - RED
#       - RED_EDGE_1
#       - RED_EDGE_2
#       - RED_EDGE_3
#       - NIR_BROAD
#       - NIR_NARROW
#       - WATER_VAPOR
#       - SWIR_1
#       - SWIR_2
#     batch_size: 1
#     num_workers: 0
#     repeat_bands:
#       DEM: 4
#     target_size: 96
# model:
#   class_path: terratorch.tasks.EmbeddingGenerationTask
#   init_args:
#     embed_file_key: filename
#     embedding_pooling: null
#     has_cls: false
#     layers:
#     - -1
#     model: terramind_v1_base
#     model_args:
#       merge_method: mean
#       modalities:
#       - S2L2A
#       - S1RTC
#       - DEM
#       pretrained: true
#     output_format: parquet
#     temporal_cfg:
#       temporal_pooling: keep
#       temporal_wrapper: true
# seed_everything: 0
# trainer:
#   accelerator: auto
#   callbacks: []
#   devices: auto
#   max_epochs: 0
#   num_nodes: 1
#   strategy: auto

# %%
model_name = yaml_config['model']['init_args']['model']
output_dir = PROCESSED_DATA_DIR / DATA_VERSION / model_name
output_dir.mkdir(exist_ok=True, parents=True)
data_root = RAW_DATA_DIR / DATA_VERSION

# add variables to yaml config so it can be passed to classes
yaml_config['data']['init_args']['data_root'] = data_root
yaml_config['model']['init_args']['output_dir'] = output_dir

# %%
chip_gdf = gpd.read_file(data_root / 'gelos_chip_tracker.geojson')

# %%
chip_gdf
# Out:
#        original_id  aoi_index                     sentinel_2_dates  \
# 0              318          0  20230218,20230419,20230713,20231230
# 1              475          0  20230218,20230419,20230713,20231230
# 2             1461          0  20230218,20230419,20230713,20231230
# 3             1550          0  20230218,20230419,20230713,20231230
# 4             1551          0  20230218,20230419,20230713,20231230
# ...            ...        ...                                  ...
# 60502       707345        410  20230301,20230619,20230724,20231126
# 60503       707365        410  20230301,20230619,20230724,20231126
# 60504       707366        410  20230301,20230619,20230724,20231126
# 60505       707388        410  20230301,20230619,20230724,20231126
# 60506       710439        411  20230220,20230426,20230913,20231008
#
#                           sentinel_1_dates  \
# 0      20230218,20230419,20230712,20231227
# 1      20230218,20230419,20230712,20231227
# 2      20230218,20230419,20230712,20231227
# 3      20230218,20230419,20230712,20231227
# 4      20230218,20230419,20230712,20231227
# ...                                    ...
# 60502  20230223,20230623,20230729,20231126
# 60503  20230223,20230623,20230729,20231126
# 60504  20230223,20230623,20230729,20231126
# 60505  20230223,20230623,20230729,20231126
# 60506  20230217,20230418,20230909,20231003
#
#                              landsat_dates  land_cover   epsg   status  \
# 0      20230217,20230524,20230921,20231218         2.0  32634  success
# 1      20230217,20230524,20230921,20231218         2.0  32634  success
# 2      20230217,20230524,20230921,20231218         2.0  32634  success
# 3      20230217,20230524,20230921,20231218         2.0  32634  success
# 4      20230217,20230524,20230921,20231218         2.0  32634  success
# ...                                    ...         ...    ...      ...
# 60502  20230301,20230402,20230723,20231027         2.0  32617  success
# 60503  20230301,20230402,20230723,20231027         2.0  32617  success
# 60504  20230301,20230402,20230723,20231027         2.0  32617  success
# 60505  20230301,20230402,20230723,20231027         2.0  32617  success
# 60506  20230329,20230601,20230921,20231124         2.0  32616  success
#
#                                     sentinel_2_scene_ids  \
# 0      S2A_MSIL2A_20230218T085021_R107_T34NEK_2023022...
# 1      S2A_MSIL2A_20230218T085021_R107_T34NEK_2023022...
# 2      S2A_MSIL2A_20230218T085021_R107_T34NEK_2023022...
# 3      S2A_MSIL2A_20230218T085021_R107_T34NEK_2023022...
# 4      S2A_MSIL2A_20230218T085021_R107_T34NEK_2023022...
# ...                                                  ...
# 60502  S2B_MSIL2A_20230301T160509_R054_T17QNE_2024081...
# 60503  S2B_MSIL2A_20230301T160509_R054_T17QNE_2024081...
# 60504  S2B_MSIL2A_20230301T160509_R054_T17QNE_2024081...
# 60505  S2B_MSIL2A_20230301T160509_R054_T17QNE_2024081...
# 60506  S2A_MSIL2A_20230220T161311_R140_T16QEJ_2023022...
#
#                                     sentinel_1_scene_ids  ...  \
# 0      S1A_IW_GRDH_1SDV_20230218T041643_20230218T0417...  ...
# 1      S1A_IW_GRDH_1SDV_20230218T041643_20230218T0417...  ...
# 2      S1A_IW_GRDH_1SDV_20230218T041643_20230218T0417...  ...
# 3      S1A_IW_GRDH_1SDV_20230218T041643_20230218T0417...  ...
# 4      S1A_IW_GRDH_1SDV_20230218T041643_20230218T0417...  ...
# ...                                                  ...  ...
# 60502  S1A_IW_GRDH_1SDV_20230223T232727_20230223T2327...  ...
# 60503  S1A_IW_GRDH_1SDV_20230223T232727_20230223T2327...  ...
# 60504  S1A_IW_GRDH_1SDV_20230223T232727_20230223T2327...  ...
# 60505  S1A_IW_GRDH_1SDV_20230223T232727_20230223T2327...  ...
# 60506  S1A_IW_GRDH_1SDV_20230217T114436_20230217T1145...  ...
#
#                                            dem_scene_ids     id        lat  \
# 0      Copernicus_DSM_COG_10_N04_00_E021_00_DEM,Coper...      0  21.825585
# 1      Copernicus_DSM_COG_10_N04_00_E021_00_DEM,Coper...      1  21.566028
# 2      Copernicus_DSM_COG_10_N04_00_E021_00_DEM,Coper...      2  21.107529
# 3      Copernicus_DSM_COG_10_N04_00_E021_00_DEM,Coper...      3  21.090230
# 4      Copernicus_DSM_COG_10_N04_00_E021_00_DEM,Coper...      4  21.098879
# ...                                                  ...    ...        ...
# 60502  Copernicus_DSM_COG_10_N22_00_W082_00_DEM,Coper...  60502 -80.011621
# 60503  Copernicus_DSM_COG_10_N22_00_W082_00_DEM,Coper...  60503 -80.011681
# 60504  Copernicus_DSM_COG_10_N22_00_W082_00_DEM,Coper...  60504 -80.002391
# 60505  Copernicus_DSM_COG_10_N22_00_W082_00_DEM,Coper...  60505 -80.067480
# 60506  Copernicus_DSM_COG_10_N21_00_W088_00_DEM,Coper...  60506 -86.977283
#
#              lon  category  color  \
# 0       4.285593      None   None
# 1       4.233723      None   None
# 2       4.094963      None   None
# 3       4.086280      None   None
# 4       4.086279      None   None
# ...          ...       ...    ...
# 60502  21.873785      None   None
# 60503  21.865113      None   None
# 60504  21.865057      None   None
# 60505  21.856766      None   None
# 60506  20.738569      None   None
#
#                                           landsat_thumbs  \
# 0      https://gelos-fm.s3.amazonaws.com/thumbnails/l...
# 1      https://gelos-fm.s3.amazonaws.com/thumbnails/l...
# 2      https://gelos-fm.s3.amazonaws.com/thumbnails/l...
# 3      https://gelos-fm.s3.amazonaws.com/thumbnails/l...
# 4      https://gelos-fm.s3.amazonaws.com/thumbnails/l...
# ...                                                  ...
# 60502  https://gelos-fm.s3.amazonaws.com/thumbnails/l...
# 60503  https://gelos-fm.s3.amazonaws.com/thumbnails/l...
# 60504  https://gelos-fm.s3.amazonaws.com/thumbnails/l...
# 60505  https://gelos-fm.s3.amazonaws.com/thumbnails/l...
# 60506  https://gelos-fm.s3.amazonaws.com/thumbnails/l...
#
#                                        sentinel_1_thumbs  \
# 0      https://gelos-fm.s3.amazonaws.com/thumbnails/s...
# 1      https://gelos-fm.s3.amazonaws.com/thumbnails/s...
# 2      https://gelos-fm.s3.amazonaws.com/thumbnails/s...
# 3      https://gelos-fm.s3.amazonaws.com/thumbnails/s...
# 4      https://gelos-fm.s3.amazonaws.com/thumbnails/s...
# ...                                                  ...
# 60502  https://gelos-fm.s3.amazonaws.com/thumbnails/s...
# 60503  https://gelos-fm.s3.amazonaws.com/thumbnails/s...
# 60504  https://gelos-fm.s3.amazonaws.com/thumbnails/s...
# 60505  https://gelos-fm.s3.amazonaws.com/thumbnails/s...
# 60506  https://gelos-fm.s3.amazonaws.com/thumbnails/s...
#
#                                        sentinel_2_thumbs  \
# 0      https://gelos-fm.s3.amazonaws.com/thumbnails/s...
# 1      https://gelos-fm.s3.amazonaws.com/thumbnails/s...
# 2      https://gelos-fm.s3.amazonaws.com/thumbnails/s...
# 3      https://gelos-fm.s3.amazonaws.com/thumbnails/s...
# 4      https://gelos-fm.s3.amazonaws.com/thumbnails/s...
# ...                                                  ...
# 60502  https://gelos-fm.s3.amazonaws.com/thumbnails/s...
# 60503  https://gelos-fm.s3.amazonaws.com/thumbnails/s...
# 60504  https://gelos-fm.s3.amazonaws.com/thumbnails/s...
# 60505  https://gelos-fm.s3.amazonaws.com/thumbnails/s...
# 60506  https://gelos-fm.s3.amazonaws.com/thumbnails/s...
#
#                                                 geometry
# 0      POLYGON ((21.82991 4.28125, 21.82992 4.28993, ...
# 1      POLYGON ((21.57035 4.22938, 21.57036 4.23806, ...
# 2      POLYGON ((21.11185 4.09062, 21.11185 4.09931, ...
# 3      POLYGON ((21.09455 4.08194, 21.09456 4.09062, ...
# 4      POLYGON ((21.1032 4.08194, 21.1032 4.09062, 21...
# ...                                                  ...
# 60502  POLYGON ((-80.00701 21.86942, -80.00695 21.878...
# 60503  POLYGON ((-80.00707 21.86075, -80.00701 21.869...
# 60504  POLYGON ((-79.99778 21.86069, -79.99772 21.869...
# 60505  POLYGON ((-80.06286 21.8524, -80.06281 21.8610...
# 60506  POLYGON ((-86.97267 20.73423, -86.97267 20.742...
#
# [60507 rows x 22 columns]

# %%
embeddings_directories = [item for item in output_dir.iterdir() if item.is_dir()]

# %%
def extract_embeddings_from_directory(directory: Path | str, n_sample: int = 100000, chip_indices: list[int] = None, time_step: int = None) -> np.array:
    # extract embeddings in numpy format from geoparquet
    if chip_indices:
        files = [directory / f"{str(id).zfill(6)}_embedding.parquet" for id in chip_indices]
    else:
        files = sample_files(directory, n_sample, seed=42)
        chip_indices = [int(file.stem.split('_')[0]) for file in files]
    dataset = ds.dataset(files, format='parquet')
    table = dataset.to_table(columns=["embedding"])
    n_rows = table.num_rows
    embeddings_column = table.column("embedding").combine_chunks()
    if time_step:
        embeddings_column = pa.compute.list_element(embeddings_column, time_step)
    embeddings_flattened = pa.compute.list_flatten(embeddings_column, recursive=True)
    embeddings = embeddings_flattened.to_numpy(zero_copy_only=False).reshape(n_rows,-1)
    return embeddings, chip_indices

def tsne_from_embeddings(embeddings: np.array) -> np.array:
    tsne = TSNE(n_components=2, random_state=42, perplexity=50, max_iter=1000)
    embeddings_tsne = tsne.fit_transform(embeddings)
    return embeddings_tsne

def plot_from_tsne(
        embeddings_tsne: np.array,
        chip_df: gpd.GeoDataFrame,
        model_name: str,
        legend_patches: list[Patch],
        chip_indices: list[int],
        axis_lim: int = 90,
        output_dir: str | Path = None
        ) -> None:
    """
    plot a tSNE transform of embeddings colored according to land cover
    """
    colors = chip_df.loc[chip_indices]['color']
    
    plt.figure(figsize=(10, 8))
    plt.scatter(embeddings_tsne[:, 1], -embeddings_tsne[:, 0], c=colors, s=2)
    plt.title(f"t-SNE Visualization of EO-FM-Bench Embeddings for {model_name}", fontsize=14)
    plt.xlabel("t-SNE Dimension 1", fontsize=12)
    plt.ylabel("t-SNE Dimension 2", fontsize=12)
    plt.xlim([-axis_lim, axis_lim])
    plt.ylim([-axis_lim, axis_lim])
    plt.legend(handles=legend_patches, loc="upper left", fontsize=10, framealpha=0.9)

    if output_dir:
        plt.savefig(output_dir / "tsne.png", dpi=600, bbox_inches="tight")
    else:
        plt.show()

# %%
land_cover_cmap = {
    "1": "#419bdf",  # Water
    "2": "#397d49",  # Trees
    "5": "#e49635",  # Crops
    "7": "#c4281b",  # Built Area
    "8": "#a59b8f",  # Bare Ground
    "11": "#e3e2c3"   # Rangeland
}
legend_patches = [
    Patch(color=color, label=name)
    for name, color in [
        ("Water", "#419bdf"),
        ("Trees", "#397d49"),
        ("Crops", "#e49635"),
        ("Built Area", "#c4281b"),
        ("Bare Ground", "#a59b8f"),
        ("Rangeland", "#e3e2c3"),
    ]
]
def get_color_from_status(land_cover: float):
    land_cover_string = str(land_cover).split('.')[0]
    hex_color = land_cover_cmap.get(land_cover_string, '#000000')
    return hex_color
chip_df['color']=chip_df['land_cover'].apply(lambda x: get_color_from_status(x))

# %%
for embeddings_directory in embeddings_directories:
    embeddings, chip_indices = extract_embeddings_from_directory(embeddings_directory, n_sample=10000, time_step=2)
    embeddings_tsne = tsne_from_embeddings(embeddings)
    plot_from_tsne(embeddings_tsne, chip_df, model_name, legend_patches, chip_indices)

# %%
yaml_config_directory = config.PROJ_ROOT / 'gelos' / 'configs'
# yaml_name = 'terramind_embedding_generation.yaml'
yaml_name = 'prithvi_eo_300m_embedding_generation.yaml'
with open(yaml_config_directory / yaml_name, "r") as f:
    yaml_config = yaml.safe_load(f)
print(yaml.dump(yaml_config))
model_name = yaml_config['model']['init_args']['model']
output_dir = PROCESSED_DATA_DIR / DATA_VERSION / model_name
output_dir.mkdir(exist_ok=True, parents=True)
data_root = RAW_DATA_DIR / DATA_VERSION

# add variables to yaml config so it can be passed to classes
yaml_config['data']['init_args']['data_root'] = data_root
yaml_config['model']['init_args']['output_dir'] = output_dir
embeddings_directories = [item for item in output_dir.iterdir() if item.is_dir()]
for embeddings_directory in embeddings_directories:
    embeddings, chip_indices = extract_embeddings_from_directory(embeddings_directory, chip_indices=chip_indices)
    embeddings_tsne = tsne_from_embeddings(embeddings)
    plot_from_tsne(embeddings_tsne, chip_df, model_name, legend_patches, chip_indices)
# Out:
# data:
#   class_path: gelos.gelosdatamodule.GELOSDataModule
#   init_args:
#     bands:
#       S2L2A:
#       - BLUE
#       - GREEN
#       - RED
#       - RED_EDGE_1
#       - NIR_BROAD
#       - NIR_NARROW
#     batch_size: 1
#     num_workers: 0
# model:
#   class_path: terratorch.tasks.EmbeddingGenerationTask
#   init_args:
#     embed_file_key: filename
#     embedding_pooling: vit_cls
#     has_cls: true
#     model: prithvi_eo_v2_300
#     model_args:
#       backbone: prithvi_eo_v2_300
#       backbone_bands:
#       - BLUE
#       - GREEN
#       - RED
#       - RED_EDGE_1
#       - NIR_BROAD
#       - NIR_NARROW
#       backbone_pretrained: true
#     output_format: parquet
# seed_everything: 0
# trainer:
#   accelerator: auto
#   callbacks: []
#   devices: auto
#   max_epochs: 0
#   num_nodes: 1
#   strategy: auto
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 17
#      15 embeddings_directories = [item for item in output_dir.iterdir() if item.is_dir()]
#      16 for embeddings_directory in embeddings_directories:
# ---> 17     embeddings, chip_indices = extract_embeddings_from_directory(embeddings_directory, chip_indices=chip_indices)
#      18     embeddings_tsne = tsne_from_embeddings(embeddings)
#      19     plot_from_tsne(embeddings_tsne, chip_df, model_name, legend_patches, chip_indices)
#
# Cell In[20], line 8, in extract_embeddings_from_directory(directory, n_sample, chip_indices, time_step)
#       6     files = sample_files(directory, n_sample, seed=42)
#       7     chip_indices = [int(file.stem.split('_')[0]) for file in files]
# ----> 8 dataset = ds.dataset(files, format='parquet')
#       9 table = dataset.to_table(columns=["embedding"])
#      10 n_rows = table.num_rows
#
# File /opt/venv/lib/python3.11/site-packages/pyarrow/dataset.py:793, in dataset(source, schema, format, filesystem, partitioning, partition_base_dir, exclude_invalid_files, ignore_prefixes)
#     791 elif isinstance(source, (tuple, list)):
#     792     if all(_is_path_like(elem) or isinstance(elem, FileInfo) for elem in source):
# --> 793         return _filesystem_dataset(source, **kwargs)
#     794     elif all(isinstance(elem, Dataset) for elem in source):
#     795         return _union_dataset(source, **kwargs)
#
# File /opt/venv/lib/python3.11/site-packages/pyarrow/dataset.py:470, in _filesystem_dataset(source, schema, filesystem, partitioning, format, partition_base_dir, exclude_invalid_files, selector_ignore_prefixes)
#     468         paths_or_selector = source
#     469     else:
# --> 470         fs, paths_or_selector = _ensure_multiple_sources(source, filesystem)
#     471 else:
#     472     fs, paths_or_selector = _ensure_single_source(source, filesystem)
#
# File /opt/venv/lib/python3.11/site-packages/pyarrow/dataset.py:379, in _ensure_multiple_sources(paths, filesystem)
#     377     continue
#     378 elif file_type == FileType.NotFound:
# --> 379     raise FileNotFoundError(info.path)
#     380 elif file_type == FileType.Directory:
#     381     raise IsADirectoryError(
#     382         f'Path {info.path} points to a directory, but only file paths are '
#     383         'supported. To construct a nested or union dataset pass '
#     384         'a list of dataset objects instead.'
#     385     )
#
# FileNotFoundError: /app/data/processed/v0.40/prithvi_eo_v2_300/layer_23/060978_embedding.parquet
