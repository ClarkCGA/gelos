# %%
import geopandas as gpd
import pandas as pd
from pathlib import Path
data_dir = Path('/app/data/interim/v0.40/layer_23')

# %%
df = pd.read_parquet(data_dir / '000001_embedding.parquet')

# %%
df.iloc[0]['embedding'].shape
# Out:
# (1024,)
