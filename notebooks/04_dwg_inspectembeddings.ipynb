# %%
import geopandas as gpd
import pandas as pd
from pathlib import Path
prithvi_dir = Path('/app/data/interim/v0.40/layer_23')
terramind_dir = Path('/app/data/interim/v0.40/layer_23')

# %%
df = pd.read_parquet(prithvi_dir / '000001_embedding.parquet')
df.iloc[0]['embedding'].shape
# Out:
# (1024,)

# %%
df = pd.read_parquet(terramind_dir / '000001_embedding.parquet')
df.iloc[0]['embedding'].shape
# Out:
# (1024,)
